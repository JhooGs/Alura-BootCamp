# %%
import pandas as pd 
import numpy as np
#Importando biblioteca gráfica do python
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

# %%
dados = pd.read_csv("./Dados/A160324189_28_143_208.csv", encoding="ISO-8859-1", 
                    skiprows =3, sep=";", skipfooter=12,engine='python',
                    thousands=".",decimal=",")

# %%
#Primeiras 5 linhas
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...     2019/Dez     2020/Jan     2020/Fev  \
# 0        -        -        -  ...   8660753.05   8326416.32   8413784.42
# 1        -        -        -  ...   2959569.09   3261123.88   2981264.22
# 2        -        -        -  ...  14923380.22  15939561.23  15138110.70
# 3        -        -        -  ...   2889969.87   3084561.08   2967159.04
# 4        -        -        -  ...  35222625.80  37009819.17  34635702.52
#
# ...

# %%
#Últimas 5 linhas
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...     2019/Dez     2020/Jan  \
# 22        -        -        -        -  ...  88720873.59  97474362.62
# 23        -        -        -        -  ...  17844511.04  18653296.92
# 24        -        -        -        -  ...  13827706.20  15445693.74
# 25        -        -        -        -  ...  34050298.55  36312121.02
# 26        -        -        -        -  ...  19207148.01  20429067.27
#
#        2020/Fev     2020/Mar     2020/Abr     2020/Mai     2020/Jun  \
# ...

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Abr    4.000568e+07
# 2020/Mai    4.676903e+07
# 2020/Jun    4.536735e+07
# 2020/Jul    4.071708e+07
# Total       5.993724e+09
# Length: 157, dtype: float64

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 280 entries, Unidade da Federação to Total
# dtypes: float64(157), object(123)
# memory usage: 59.2+ KB

# %%
#Formatando globalmente as informações para ter duas casas decimais depois da vírgula
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Abr     40005678.92
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# Total      5993724452.01
# Length: 157, dtype: float64

# %%
dados["2008/Jan"]
# Out:
# 0       1829559.71
# 1       1731744.62
# 2      11419210.08
# 3        808448.39
# 4      21762104.16
# 5       1329876.61
# 6       5136474.61
# 7      21551600.33
# 8      11375419.37
# 9      32444328.54
# 10     11763899.23
# 11     16599004.84
# 12     51219113.60
# 13     16503978.22
# 14      5439985.99
# 15     73336297.08
# 16    205912743.65
# 17     16212109.41
# 18    250564959.99
# 19   1023564534.21
# 20     58081334.45
# 21     53034384.67
# 22     51064610.03
# 23      8301006.10
# 24      8213438.64
# 25     74063828.22
# 26     10561085.46
# Name: 2008/Jan, dtype: float64

# %%
dados.plot(x="Unidade da Federação", 
                y="2008/Ago", 
                kind="bar",
                figsize=(12,6))

# %%
#ax é conhecido como axis
ax = dados.plot(x="Unidade da Federação", y="2008/Ago", kind="bar",figsize=(12,6))
#Mudar a forma como os dados do eixo Y são exibidos
#x:,.2f => x é só uma letra simbolizando que vai ser alterado, a vírgula é o separador de milhar e .2f é ponto flutuante com duas casas decimais 
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))
plt.title("Valores gastos por unidade da Federação em procedimentos hospitalares")
#Evita que apareça informações que não precisam aparecer
plt.show()

# %%
#Existe um Dash (-) na informação númerica, transformando o tipo da coluna em object e impossibilitando a plotagem do gráfico
#Aqui eu faço um replace desse caractere para Nan
dados["2020/Ago"].replace('-',np.nan,regex=True, inplace=True)

# %%
#Transformado a Dash em um valor nulo podemos transformar a coluna em float e plotar
dados["2020/Ago"] =  dados["2020/Ago"].astype(float)

# %%
dados["2020/Ago"]
# Out:
# 0      3556381.57
# 1             nan
# 2      4726485.73
# 3      1524478.04
# 4     11559714.54
# 5       834187.31
# 6      2453362.74
# 7     10916718.78
# 8      7926321.69
# 9     14559529.59
# 10     8080160.97
# 11     8585226.08
# 12    33544876.14
# 13     6487947.82
# 14     1742127.72
# 15    26023558.53
# 16    57473699.06
# 17    10824255.26
# 18    36264322.65
# 19   140414944.95
# 20    41542401.16
# 21    16991236.43
# 22    28349257.38
# 23     4059220.22
# 24     6174224.99
# 25    20242641.73
# 26    12044848.02
# Name: 2020/Ago, dtype: float64

# %%
#ax é conhecido como axis
ax = dados.plot(x="Unidade da Federação", y="2020/Ago", kind="bar",figsize=(12,6))
#Mudar a forma como os dados do eixo Y são exibidos
#x:,.2f => x é só uma letra simbolizando que vai ser alterado, a vírgula é o separador de milhar e .2f é ponto flutuante com duas casas decimais 
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))
plt.title("Valores gastos por unidade da Federação em procedimentos hospitalares")
#Evita que apareça informações que não precisam aparecer
plt.show()

# %%
#Para chamar mais de uma coluna usamos dois colchetes para simbolizar que são duas nomes distintos 
dados[["2008/Ago","2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
#Note que a primeira coluna que ele faz a média é 2007, mesmo nosso data frame começando em 1992
#Isso ocorre porque ele só faz o calculo onde todas as colunas possuem todos os dados preenchidos
#Sendo mais específico, a coluna se torna um object caso tenha algo diferente de número, impossibilitando calculos
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Mai     46769027.82
# 2020/Jun     45367349.74
# 2020/Jul     40717083.95
# 2020/Ago     19880851.12
# Total      5993724452.01
# Length: 158, dtype: float64

# %%
#Aqui pegamos apenas a primeira coluna e transformamos em uma lista (uma lista permite que a mesma seja alterada depois)
colunas_usaveis = dados.mean().index.tolist()
#Aqui nós vamos alterar a lista e inserir na posição 0 a coluna "Unidade da Federação" (Se a gente não transformar em lista, não poderíamos inserir essa informação)
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
#Usando colunas_usaveis como filtro para trazer nosso dataset apenas onde as colunas estão completamente preenchidas
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2019/Dez  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ...  8660753.05
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  2959569.09
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 14923380.22
# 3   808448.39   771687.83   876091.18   896952.53  ...  2889969.87
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 35222625.80
#
#      2020/Jan    2020/Fev    2020/Mar    2020/Abr    2020/Mai    2020/Jun  \
# ...

# %%
#Tranformando o indice da coluna que era 0,1,2,3... nas unidades da federação
usaveis = usaveis.set_index("Unidade da Federação")

# %%
usaveis
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia               4209.37   16397.03   133645.19   346912.84
# 12 Acre                  10470.07   14001.71    86200.85   301323.68
# 13 Amazonas              35752.72   45570.64   416012.30  2020381.79
# 14 Roraima                4785.91   11858.63    43852.67   369328.51
# 15 Pará                 181159.29  433414.74  1893197.50  5105406.44
# 16 Amapá                 33672.74  104822.98   118378.28   226661.18
# 17 Tocantins              4113.76   76633.06   343702.61  1068685.94
# 21 Maranhão             385330.18 1018352.93  2277717.78  4334468.23
# 22 Piauí                220788.25  353468.67  1078182.68  2406035.32
# 23 Ceará                357904.65  572356.18  1865065.71  5131814.39
# 24 Rio Grande do Norte  134605.36  272088.08   684678.30  1695824.89
# 25 Paraíba               97352.78  368130.43  1002088.64  2149873.40
# ...

# %%
usaveis["2019/Ago"]
# Out:
# Unidade da Federação
# 11 Rondônia                8909111.89
# 12 Acre                    2981072.98
# 13 Amazonas               16493719.52
# 14 Roraima                 3181321.82
# 15 Pará                   36462011.47
# 16 Amapá                   2173060.89
# 17 Tocantins               7140062.79
# 21 Maranhão               31374191.37
# 22 Piauí                  17816404.11
# 23 Ceará                  51672585.01
# 24 Rio Grande do Norte    23073307.72
# 25 Paraíba                19854699.54
# 26 Pernambuco             71735626.96
# 27 Alagoas                17668105.59
# 28 Sergipe                10075280.52
# 29 Bahia                  77852441.31
# 31 Minas Gerais          161707825.05
# 32 Espírito Santo         29298721.79
# 33 Rio de Janeiro         83311603.59
# 35 São Paulo             302367276.77
# 41 Paraná                127174095.05
# 42 Santa Catarina         64503540.72
# 43 Rio Grande do Sul      98546110.10
# 50 Mato Grosso do Sul     19217982.14
# ...

# %%
#Localiza a linha onde seja "12 Acre"
usaveis.loc["12 Acre"]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Mai     2383895.48
# 2020/Jun     2199920.70
# 2020/Jul     1163813.08
# 2020/Ago            nan
# Total      420668039.63
# Name: 12 Acre, Length: 158, dtype: float64

# %%
#Aqui a tabela for transportada ou seja invertida
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
#Gráfico está distorcido por causa do valor do total
usaveis.T.plot(figsize=(10,6))

# %%
#vamos dropar a coluna "Total" para deixar o gráfico mais vísivel 
#Axis = 0 É a linha
#Axis = 1 É a coluna
usaveis = usaveis.drop("Total",axis=1)

# %%
#Gráfico está distorcido por causa do valor do total
usaveis.T.plot(figsize=(14,6))

# %%
#Desafio 1: Arrumar a legenda

ax = usaveis.T.plot(figsize=(16,6))

plt.title("Valores por Processamento x Data atendimento")
#ncol signigica o número de colunas que a legenda vai ter
#bbox_to_anchor : é a posição no eixo X e Y da legenda, se voc add outra virgula pode colocar largura e altura
leg = ax.legend(loc='lower center', ncol=9, frameon=True,title='Unidades da Federação', bbox_to_anchor=(0.5, -0.35))
#Formatando eixo Y para real
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))

# %%
#Desafio 2: Plotar 5 estados 

desa2 = usaveis.loc[["41 Paraná","12 Acre","31 Minas Gerais","42 Santa Catarina","53 Distrito Federal"]]

# %%
ax = desa2.T.plot(figsize=(14,8))
plt.title("Valores por Processamento x Data atendimento")
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))
ax.legend(loc='best',frameon=True,title='Unidades da Federação', bbox_to_anchor=(1, 1))
plt.show()

# %%
#Define uma semente de aleatoriedade a partir desse número
np.random.seed(687942)

# Retira uma amostra aleatória
usaveis.sample(n=7)
# Out:
#                         2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 32 Espírito Santo       57408.11  284224.80  1152115.25  2296383.23
# 31 Minas Gerais        971394.37 2861781.50 10018011.35 21730281.63
# 24 Rio Grande do Norte 134605.36  272088.08   684678.30  1695824.89
# 17 Tocantins             4113.76   76633.06   343702.61  1068685.94
# 53 Distrito Federal    191951.47  769966.25  2165619.56  3813256.48
# 50 Mato Grosso do Sul  199556.12  573675.41  1069816.66  1995899.52
# 16 Amapá                33672.74  104822.98   118378.28   226661.18
#
#                           2007/Dez     2008/Jan    2008/Fev    2008/Mar  \
# Unidade da Federação
# 32 Espírito Santo       5724199.54  16212109.41 10032886.43 12262049.08
# 31 Minas Gerais        43429517.54 205912743.65 70301089.50 79119005.51
# 24 Rio Grande do Norte  4730811.68  11763899.23  9110108.87 10126626.54
# 17 Tocantins            3022200.87   5136474.61  5051932.07  5200151.87
# ...

# %%
#Soma das linhas, ou seja eixo 1
usaveis.sum(axis=1)
# Out:
# Unidade da Federação
# 11 Rondônia                929129055.39
# 12 Acre                    420666755.81
# 13 Amazonas               1771652039.82
# 14 Roraima                 305010469.49
# 15 Pará                   4437097195.11
# 16 Amapá                   291615887.03
# 17 Tocantins               999960604.09
# 21 Maranhão               3632801824.38
# 22 Piauí                  2130602528.98
# 23 Ceará                  6197345931.63
# 24 Rio Grande do Norte    2477315927.36
# 25 Paraíba                2470526884.71
# 26 Pernambuco             8046679981.91
# 27 Alagoas                2104391371.86
# 28 Sergipe                1130327450.81
# 29 Bahia                  9193757249.74
# 31 Minas Gerais          19159574431.00
# 32 Espírito Santo         3139177454.95
# 33 Rio de Janeiro         9696202329.77
# 35 São Paulo             38919478583.07
# 41 Paraná                13786791386.76
# 42 Santa Catarina         7323960945.94
# 43 Rio Grande do Sul     11958530351.36
# ...

# %%
#Criando uma coluna total para cada estado
usaveis["Total"] = usaveis.sum(axis=1)

# %%
#Desafio 1: Incluir nova coluna com regiões: Norte, Sul .....

#Exemplo de um aluno da alura 

# contruido dicionario para fazer colocar as regioes
#regiao_dict={'1': 'Norte',
#             '2': 'Nordeste',
#            '3': 'Sudeste',
#             '4': 'Sul',
#             '5': 'Centro-Oeste'}
#usaveis_regiao = usaveis.copy()
#usaveis_regiao['Regiao'] = usaveis_regiao.index.str[0].map(regiao_dict)
# usado map para substituir valores por dicionario selecionado só o primeiro string
#usaveis_regiao['Regiao'].unique()

# %%
# index.str.get retorna a string na posição que você estipular
usaveis.index.str.get(3)
# Out:
# Index(['R', 'A', 'A', 'R', 'P', 'A', 'T', 'M', 'P', 'C', 'R', 'P', 'P', 'A',
#        'S', 'B', 'M', 'E', 'R', 'S', 'P', 'S', 'R', 'M', 'M', 'G', 'D'],
#       dtype='object', name='Unidade da Federação')

# %%
#Usando regex para localizar campos que comecem com 1, mas o resultado não é muito bom
usaveis.index.str.match('^1')
# Out:
# array([ True,  True,  True,  True,  True,  True,  True, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
# Vamos criar um dicionário (DePara Região <> Nº)
regiao = {1 : 'Norte',
          2 : 'Nordeste',
          3 : 'Sudeste',
          4 : 'Sul',
          5 : 'Centro-Oeste'
          }
regiao
# Out:
# {1: 'Norte', 2: 'Nordeste', 3: 'Sudeste', 4: 'Sul', 5: 'Centro-Oeste'}

# %%
# Cria uma coluna chamada Regiao e atribuímos à ela o número do primeiro elemento do indice
# Exemplo: 12 Acre, primeiro elemento é 1 logo atribuímos 1 a Região

usaveis["Regiao"] = usaveis.index.str.get(0).to_list()
usaveis["Regiao"] = usaveis["Regiao"].astype('int')

usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
# O map atribui um valor a um elemento
#Como a gente criou um dicionario mostrando o que significa cada número, ele vai se basear nele e substituir o valor da coluna pelo nome

usaveis['Regiao'] = usaveis['Regiao'].map(regiao)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
usaveis.sample(10)
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 42 Santa Catarina     693955.05 1092964.12  3562300.82  7578502.38
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 21 Maranhão           385330.18 1018352.93  2277717.78  4334468.23
# 52 Goiás              179395.82  418053.58  1198730.25  2712117.54
# 32 Espírito Santo      57408.11  284224.80  1152115.25  2296383.23
# 28 Sergipe             27453.63   78565.19   122952.94   775705.52
# 13 Amazonas            35752.72   45570.64   416012.30  2020381.79
# 14 Roraima              4785.91   11858.63    43852.67   369328.51
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 42 Santa Catarina    14772555.10   53034384.67  24409572.92  27483480.50
# ...

# %%
#Ordenar pelo Total
ordenado_por_total = usaveis.sort_values("Total", ascending=False)
#Excluindo coluna total para nã odar discrepância na informação
ordenado_por_total = ordenado_por_total.drop("Total", axis = 1)
#Excluir coluna Regiao pois não é numerica para plotar 
ordenado_por_total = ordenado_por_total.drop("Regiao", axis = 1)
ordenado_por_total.head(10)
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
# 29 Bahia              135146.36  448349.75  1382038.11  3348779.62
# 26 Pernambuco         400640.85 1088340.42  2973553.48  6699828.82
# 42 Santa Catarina     693955.05 1092964.12  3562300.82  7578502.38
# 23 Ceará              357904.65  572356.18  1865065.71  5131814.39
# 52 Goiás              179395.82  418053.58  1198730.25  2712117.54
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1023564534.21 172834914.73 170481849.56
# ...

# %%
#DESAFIO 3: DEIXAR MAIS BONITO O GRÁFICO
ax = ordenado_por_total.head(5).T.plot(figsize=(16,8),colormap= 'Dark2', fontsize=14)
plt.title("Estados que gastaram mais")
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))
ax.legend(loc='best',frameon=True,title='Unidades da Federação', bbox_to_anchor=(1, 1))

plt.style.use('ggplot')
plt.xticks(rotation=45)
plt.show()

# %%
ordenado_por_total
# Out:
#                          2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo           1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais         971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná               554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul   1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro       469469.34  921646.57  2994664.57  7250528.08
# 29 Bahia                135146.36  448349.75  1382038.11  3348779.62
# 26 Pernambuco           400640.85 1088340.42  2973553.48  6699828.82
# 42 Santa Catarina       693955.05 1092964.12  3562300.82  7578502.38
# 23 Ceará                357904.65  572356.18  1865065.71  5131814.39
# 52 Goiás                179395.82  418053.58  1198730.25  2712117.54
# 15 Pará                 181159.29  433414.74  1893197.50  5105406.44
# 21 Maranhão             385330.18 1018352.93  2277717.78  4334468.23
# ...

# %%
#DESAFIO 4: INCLUIR UM ESTADO NO GRÁFICO 

#Estou criando uma variavel e setando nela um slice do data set, como já está ordenado eu só pego os 5 primeiros e transforma em uma lista
ordenado_por_total_mais_estado = ordenado_por_total.T.columns[0:5].tolist()
#Nessa variavel estou colocando mais um estado de minha escolha
ordenado_por_total_mais_estado.append("42 Santa Catarina")
#Aqui eu crio um variavel que recebe o data set inicial com o slice da variavel que eu criei antes, para mostrar os 5 primeiros estados mais o que eu escolhi
meu_estado = ordenado_por_total.loc[ordenado_por_total_mais_estado]

# %%
ax = meu_estado.T.plot(figsize=(16,8),colormap= 'Dark2', fontsize=14)
plt.title("Estados que gastaram mais")
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))
ax.legend(loc='best',frameon=True,title='Unidades da Federação', bbox_to_anchor=(1, 1))

plt.style.use('ggplot')
#rotacionando a legenda
plt.xticks(rotation=45)
plt.show()

# %%
#Verificando outliers

#Retirando as 5 primeiras colunas, porque possuem outliers
colunas_interessadas = ordenado_por_total.columns[6:]
#atribuindo a varíavel
ordenado_por_total = ordenado_por_total[colunas_interessadas]

# %%
ordenado_por_total
# Out:
#                            2008/Fev     2008/Mar     2008/Abr     2008/Mai  \
# Unidade da Federação
# 35 São Paulo           172834914.73 170481849.56 170278285.95 172402180.59
# 31 Minas Gerais         70301089.50  79119005.51  79046322.41  79268070.12
# 41 Paraná               48855046.46  55611791.07  56115135.82  55574831.93
# 43 Rio Grande do Sul    45897704.82  52928695.92  51972416.77  51679350.79
# 33 Rio de Janeiro       44122593.19  42892665.52  45295962.86  43951349.46
# 29 Bahia                33410124.06  41301703.40  42826993.62  42071294.17
# 26 Pernambuco           26222079.10  30716361.81  30589332.79  31409553.23
# 42 Santa Catarina       24409572.92  27483480.50  27806641.44  28354279.52
# 23 Ceará                27643304.86  30085370.22  31376221.00  31189904.62
# 52 Goiás                18149374.27  20992213.03  21049477.30  19162546.79
# 15 Pará                 20126081.01  22149375.82  23436682.75  23861080.80
# ...

# %%
ax = ordenado_por_total.head(10).T.plot(figsize=(16,8),colormap= 'Dark2', fontsize=14)
plt.title("Estados que gastaram mais")
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))
ax.legend(loc='best',frameon=True,title='Unidades da Federação', bbox_to_anchor=(1, 1))

plt.style.use('ggplot')
plt.xticks(rotation=45)
plt.show()

# %%
#Plotar gráfico da região sudeste e verificar se fica igual
regiao_sudeste = usaveis.query('Regiao == "Sudeste"')
#Retirando coluna Regiao por ser string e não da para plotar
regiao_sudeste = regiao_sudeste.drop("Regiao", axis = 1)

colunas_interessadas_sudeste = ordenado_por_total.columns[6:]
regiao_sudeste = regiao_sudeste[colunas_interessadas_sudeste]

# %%
ax = regiao_sudeste.T.plot(figsize=(16,8),colormap= 'Dark2', fontsize=14)
plt.title("Estados que gastaram mais")
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))
ax.legend(loc='best',frameon=True,title='Unidades da Federação', bbox_to_anchor=(1, 1))

plt.style.use('ggplot')
plt.xticks(rotation=45)
plt.show()

# %%
#Diminuindo escala dos números
ordenado_por_total_teste = ordenado_por_total / 1000000
ax = ordenado_por_total_teste.T.plot(figsize=(16,8),colormap= 'Dark2', fontsize=14)
plt.title("Estados que gastaram mais")
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter('R$ {x:,.2f}'))
ax.legend(loc='best',frameon=True,title='Unidades da Federação', bbox_to_anchor=(1, 1))

plt.style.use('ggplot')
plt.xticks(rotation=45)
plt.show()

# %%
#Fazendo corte no gráfico para ser exibido desde 2012 a 2019
meses_filtrados = ordenado_por_total.columns[47:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(16,8))

# %%
meses_filtrados
# Out:
# Index(['2012/Jan', '2012/Fev', '2012/Mar', '2012/Abr', '2012/Mai', '2012/Jun',
#        '2012/Jul', '2012/Ago', '2012/Set', '2012/Out',
#        ...
#        '2019/Out', '2019/Nov', '2019/Dez', '2020/Jan', '2020/Fev', '2020/Mar',
#        '2020/Abr', '2020/Mai', '2020/Jun', '2020/Jul'],
#       dtype='object', length=103)

# %%
#Pegando o último mês
mes_mais_recente = ordenado_por_total.columns[-2]
mes_mais_recente
# Out:
# '2020/Jul'

# %%
gastos_do_mais_recente =  ordenado_por_total[mes_mais_recente]
gastos_do_mais_recente.head()
# Out:
# Unidade da Federação
# 35 São Paulo           282709570.31
# 31 Minas Gerais        120467187.34
# 41 Paraná               80320852.69
# 43 Rio Grande do Sul    78929703.81
# 33 Rio de Janeiro       71540227.33
# Name: 2020/Jul, dtype: float64

# %%
gastos_do_mais_recente.plot(kind='pie', figsize=(20,6))
#Nunca use gráfico que tem nome de comida

# %%
#Comparando em porcentagem os gastos com o estado do Paraná
comparaPR = gastos_do_mais_recente / gastos_do_mais_recente.loc["41 Paraná"]
comparaSC = gastos_do_mais_recente / gastos_do_mais_recente.loc["42 Santa Catarina"]

# %%
#Estamos ordenando pelo total, embora a gente esteja plotando apenas um mês, precisamos ordenar esse mês
comparaPR.plot(kind='bar', figsize=(16,8), linewidth=0.5,linestyle='-')

# %%
#Ordenando os dados pelo valor do mês
comparaPR = comparaPR.sort_values(ascending = False)
comparaPR.plot(kind='bar', figsize=(16,8), linewidth=0.5,linestyle='-')
plt.xticks(rotation=45)
plt.show()

# %%
#Ordenando os dados pelo valor do mês
comparaPR = comparaPR.sort_values(ascending = False)
comparaSC = comparaSC.sort_values(ascending = False)

plt.subplot(121)
comparaPR.plot(kind='bar', figsize=(18,6),color='blue')
plt.subplot(122)
comparaSC.plot(kind='bar', figsize=(18,6))

plt.show()

# %%
#Populações de cada estado
pop_parana = 11000008
pop_catarina = 7165000

# %%
#Valor do gasto público do sus por pessoa (mês)
gastos_do_mais_recente['41 Paraná']/ pop_parana
# Out:
# 7.301890388625171

# %%
#Valor do gasto público do sus por pessoa (mês)
gastos_do_mais_recente['42 Santa Catarina']/ pop_catarina
# Out:
# 7.22463848709002
